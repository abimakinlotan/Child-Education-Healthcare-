# %%
import pandas as pd

# %%
import numpy as np

# %%
worldEd = pd.read_csv("C:/Users/lien0/Downloads/Table-11-Education-SOWC2021-EN.csv")
worldEd.head(25)
# Out:
#     TABLE 11. EDUCATION                         Unnamed: 1  Unnamed: 2  \
# 0                   NaN                                NaN         NaN
# 1   Countries and areas                   Equitable access         NaN
# 2                   NaN  Out-of-school rate\n2013–2019 (R)         NaN
# 3                   NaN  One year before primary entry age         NaN
# 4                   NaN                               Male         NaN
# 5                   NaN                                NaN         NaN
# 6           Afghanistan                                  -         NaN
# 7               Albania                                  4         NaN
# 8               Algeria                                  -         NaN
# 9               Andorra                                  -         NaN
# 10               Angola                                 31         NaN
# 11             Anguilla                                 14         NaN
# ...

# %%
worldEd = worldEd.dropna(axis='columns', how = 'all')
worldEd = worldEd.dropna(axis='rows', how = 'all')
worldEd.head(25)
# Out:
#     TABLE 11. EDUCATION                         Unnamed: 1 Unnamed: 3  \
# 1   Countries and areas                   Equitable access        NaN
# 2                   NaN  Out-of-school rate\n2013–2019 (R)        NaN
# 3                   NaN  One year before primary entry age        NaN
# 4                   NaN                               Male     Female
# 6           Afghanistan                                  -          -
# 7               Albania                                  4          2
# 8               Algeria                                  -          -
# 9               Andorra                                  -          -
# 10               Angola                                 31         39
# 11             Anguilla                                 14          -
# 12  Antigua and Barbuda                                 14          4
# 13            Argentina                                  2          2
# ...

# %%
worldEd.fillna('', inplace=True)
worldEd.head(25)
# Out:
#     TABLE 11. EDUCATION                         Unnamed: 1 Unnamed: 3  \
# 1   Countries and areas                   Equitable access
# 2                        Out-of-school rate\n2013–2019 (R)
# 3                        One year before primary entry age
# 4                                                     Male     Female
# 6           Afghanistan                                  -          -
# 7               Albania                                  4          2
# 8               Algeria                                  -          -
# 9               Andorra                                  -          -
# 10               Angola                                 31         39
# 11             Anguilla                                 14          -
# 12  Antigua and Barbuda                                 14          4
# 13            Argentina                                  2          2
# 14              Armenia                                 52         50
# ...

# %%
sowc = pd.read_csv("C:/Users/lien0/Downloads/SOWC-Statistical-tables-ALL-2021-EN.csv")
sowc.head(25)
# Out:
#    TABLE 13. SOCIAL PROTECTION AND EQUITY  \
# 0                                     NaN
# 1                     Countries and areas
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                             Afghanistan
# 6                                 Albania
# 7                                 Algeria
# 8                                 Andorra
# 9                                  Angola
# 10                               Anguilla
# 11                    Antigua and Barbuda
# 12                              Argentina
# 13                                Armenia
# 14                              Australia
# 15                                Austria
# 16                             Azerbaijan
# 17                                Bahamas
# 18                                Bahrain
# 19                             Bangladesh
# 20                               Barbados
# ...

# %%
soxc = sowc.dropna(axis='columns', how = 'all')
sowc = sowc.dropna(axis='rows', how = 'all')
sowc.head(25)
# Out:
#    TABLE 13. SOCIAL PROTECTION AND EQUITY  \
# 1                     Countries and areas
# 3                                     NaN
# 5                             Afghanistan
# 6                                 Albania
# 7                                 Algeria
# 8                                 Andorra
# 9                                  Angola
# 10                               Anguilla
# 11                    Antigua and Barbuda
# 12                              Argentina
# 13                                Armenia
# 14                              Australia
# 15                                Austria
# 16                             Azerbaijan
# 17                                Bahamas
# 18                                Bahrain
# 19                             Bangladesh
# 20                               Barbados
# 21                                Belarus
# 22                                Belgium
# 23                                 Belize
# ...

# %%
sowc.fillna('', inplace=True)
sowc.head(25)
# Out:
#    TABLE 13. SOCIAL PROTECTION AND EQUITY  \
# 1                     Countries and areas
# 3
# 5                             Afghanistan
# 6                                 Albania
# 7                                 Algeria
# 8                                 Andorra
# 9                                  Angola
# 10                               Anguilla
# 11                    Antigua and Barbuda
# 12                              Argentina
# 13                                Armenia
# 14                              Australia
# 15                                Austria
# 16                             Azerbaijan
# 17                                Bahamas
# 18                                Bahrain
# 19                             Bangladesh
# 20                               Barbados
# 21                                Belarus
# 22                                Belgium
# 23                                 Belize
# 24                                  Benin
# ...

# %%
adolescent = pd.read_csv("C:/Users/lien0/Downloads/Table-5-Adolescent-Health-SOWC2021-EN.csv")
adolescent.head(20)
# Out:
#    TABLE 5. ADOLESCENT HEALTH                       Unnamed: 1  Unnamed: 2  \
# 0                         NaN                              NaN         NaN
# 1         Countries and areas  Adolescent mortality rate\n2019         NaN
# 2                         NaN                       Aged 10−19         NaN
# 3                         NaN                            Total         NaN
# 4                         NaN                              NaN         NaN
# 5                 Afghanistan                               15         NaN
# 6                     Albania                                3         NaN
# 7                     Algeria                                4         NaN
# 8                     Andorra                                2         NaN
# 9                      Angola                               19         NaN
# 10                   Anguilla                                -         NaN
# ...

# %%
adolescent = adolescent.dropna(axis='columns', how = 'all')
adolescent = adolescent.dropna(axis='rows', how = 'all')
adolescent.head(25)
# Out:
#           TABLE 5. ADOLESCENT HEALTH                       Unnamed: 1  \
# 1                Countries and areas  Adolescent mortality rate\n2019
# 2                                NaN                       Aged 10−19
# 3                                NaN                            Total
# 5                        Afghanistan                               15
# 6                            Albania                                3
# 7                            Algeria                                4
# 8                            Andorra                                2
# 9                             Angola                               19
# 10                          Anguilla                                -
# 11               Antigua and Barbuda                                3
# 12                         Argentina                                4
# 13                           Armenia                                3
# ...

# %%
adolescent.drop(adolescent.columns[[5, 7, 9, ]], axis = 1, inplace = True)
adolescent.head(20)
# Out:
#    TABLE 5. ADOLESCENT HEALTH                       Unnamed: 1  \
# 1         Countries and areas  Adolescent mortality rate\n2019
# 2                         NaN                       Aged 10−19
# 3                         NaN                            Total
# 5                 Afghanistan                               15
# 6                     Albania                                3
# 7                     Algeria                                4
# 8                     Andorra                                2
# 9                      Angola                               19
# 10                   Anguilla                                -
# 11        Antigua and Barbuda                                3
# 12                  Argentina                                4
# 13                    Armenia                                3
# 14                  Australia                                2
# 15                    Austria                                2
# ...

# %%
adolescent.drop(adolescent.columns[[8]], axis = 1, inplace = True)
adolescent.head()
# Out:
#   TABLE 5. ADOLESCENT HEALTH                       Unnamed: 1  \
# 1        Countries and areas  Adolescent mortality rate\n2019
# 2                        NaN                       Aged 10−19
# 3                        NaN                            Total
# 5                Afghanistan                               15
# 6                    Albania                                3
#
#                 Unnamed: 3                                         Unnamed: 5  \
# 1  Adolescent deaths\n2019  Annual rate of reduction in the adolescent mor...
# 2               Aged 10−19                                         Aged 10-19
# 3                    Total                                              Total
# 5                   14,329                                               -0.9
# 6                      105                                                3.3
#
#                              Unnamed: 7  \
# 1  Adolescent birth rate\n2015–2020 (R)
# ...

# %%
adolescent.drop(adolescent.columns[[9]], axis = 1, inplace = True)
adolescent.head()
# Out:
#   TABLE 5. ADOLESCENT HEALTH                       Unnamed: 1  \
# 1        Countries and areas  Adolescent mortality rate\n2019
# 2                        NaN                       Aged 10−19
# 3                        NaN                            Total
# 5                Afghanistan                               15
# 6                    Albania                                3
#
#                 Unnamed: 3                                         Unnamed: 5  \
# 1  Adolescent deaths\n2019  Annual rate of reduction in the adolescent mor...
# 2               Aged 10−19                                         Aged 10-19
# 3                    Total                                              Total
# 5                   14,329                                               -0.9
# 6                      105                                                3.3
#
#                              Unnamed: 7  \
# 1  Adolescent birth rate\n2015–2020 (R)
# ...

# %%
adolescent.fillna('', inplace=True)
adolescent.head(25)
# Out:
#           TABLE 5. ADOLESCENT HEALTH                       Unnamed: 1  \
# 1                Countries and areas  Adolescent mortality rate\n2019
# 2                                                          Aged 10−19
# 3                                                               Total
# 5                        Afghanistan                               15
# 6                            Albania                                3
# 7                            Algeria                                4
# 8                            Andorra                                2
# 9                             Angola                               19
# 10                          Anguilla                                -
# 11               Antigua and Barbuda                                3
# 12                         Argentina                                4
# 13                           Armenia                                3
# ...
